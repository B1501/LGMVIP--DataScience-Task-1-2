# %% [markdown]
# <a href="https://colab.research.google.com/github/B1501/LGMVIP--DataScience-Task-1-2/blob/main/Task_1_2_Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the modules**

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # **Loading the original image**

# %%
img_sketch = cv2.imread("/content/image2.jpeg")

# %% [markdown]
# # **Reading the original image in RGB Fomat**

# %%
img_sketch = cv2.cvtColor(img_sketch,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(7,7))
plt.imshow(img_sketch)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# # **Converting Image to GrayScale**

# %%
img_sketch_gray = cv2.cvtColor(img_sketch, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(7,7))
plt.imshow(img_sketch_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# # **Inverting the grayscale image**

# %%
img_sketch_invert = cv2.bitwise_not(img_sketch_gray)
plt.figure(figsize=(7,7))
plt.imshow(img_sketch_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# # **Smoothing the image**
# we need to be make sure the sketch we obtain is less edgy and smooth.

# %%
img_smoothing = cv2.GaussianBlur(img_sketch_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(7,7))
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# #**Final Image to Pencil Sketch**

# %%
final_pencil_sketch = cv2.divide(img_sketch_gray, 255 - img_smoothing, scale=255)
plt.figure(figsize=(7,7))
plt.imshow(final_pencil_sketch,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# # **Final Output**
# Displaying all the images in one frame using the subplots.

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,5,1)
plt.imshow(img_sketch)
plt.axis("off")
plt.title("Original Image with RGB format")
plt.subplot(1,5,2)
plt.imshow(img_sketch_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.subplot(1,5,3)
plt.imshow(img_sketch_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.subplot(1,5,4)
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.subplot(1,5,5)
plt.imshow(final_pencil_sketch,cmap="gray")
plt.axis("off")
plt.title("Final Pencil Sketch Image")
plt.show()
